# %% [markdown]
# # ASTROPI CSV ANALYSIS

# %% [markdown]
# ## Loading csv file

# %%
# !git clone https://github.com/jcb55/iss-astro-pi-data-browser
# Out:
# fatal: destination path 'iss-astro-pi-data-browser' already exists and is not an empty directory.

# %%
import warnings
warnings.filterwarnings('ignore')

# %matplotlib widget
import matplotlib.pyplot as plt

import pandas as pd
prova = pd.read_csv('iss-astro-pi-data-browser/Columbus_Ed_astro_pi_datalog.csv.gz')

# %% [markdown]
# ## Exploring

# %%
prova.columns
# Out:
# Index(['ROW_ID', 'temp_cpu', 'temp_h', 'temp_p', 'humidity', 'pressure',
#        'pitch', 'roll', 'yaw', 'mag_x', 'mag_y', 'mag_z', 'accel_x', 'accel_y',
#        'accel_z', 'gyro_x', 'gyro_y', 'gyro_z', 'reset', 'time_stamp'],
#       dtype='object')

# %%
prova[['temp_cpu', 'temp_h', 'temp_p', 'humidity', 'pressure', 'time_stamp']].head()
# Out:
#    temp_cpu  temp_h  temp_p  humidity  pressure           time_stamp
# 0     31.88   27.57   25.01     44.94   1001.68  2016-02-16 10:44:40
# 1     31.79   27.53   25.01     45.12   1001.72  2016-02-16 10:44:50
# 2     31.66   27.53   25.01     45.12   1001.72  2016-02-16 10:45:00
# 3     31.69   27.52   25.01     45.32   1001.69  2016-02-16 10:45:10
# 4     31.66   27.54   25.01     45.18   1001.71  2016-02-16 10:45:20

# %%
prova[['temp_cpu', 'temp_h', 'temp_p', 'humidity', 'pressure', 'time_stamp']].tail()
# Out:
#         temp_cpu  temp_h  temp_p  humidity  pressure           time_stamp
# 110864     31.56   27.52   24.83     42.94   1005.83  2016-02-29 09:24:21
# 110865     31.55   27.50   24.83     42.72   1005.85  2016-02-29 09:24:30
# 110866     31.58   27.50   24.83     42.83   1005.85  2016-02-29 09:24:41
# 110867     31.62   27.50   24.83     42.81   1005.88  2016-02-29 09:24:50
# 110868     31.57   27.51   24.83     42.94   1005.86  2016-02-29 09:25:00

# %%
prova.describe().T
# Out:
#              count          mean           std          min           25%  \
# ROW_ID    110869.0  5.543500e+04  32005.267835     1.000000  27718.000000
# temp_cpu  110869.0  3.223626e+01      0.360289    31.410000     31.960000
# temp_h    110869.0  2.810177e+01      0.369256    27.200000     27.840000
# temp_p    110869.0  2.554327e+01      0.380877    24.530000     25.260000
# humidity  110869.0  4.625201e+01      1.907273    42.270000     45.230000
# pressure  110869.0  1.008127e+03      3.093485  1001.560000   1006.090000
# pitch     110869.0  2.770553e+00     21.848940     0.000000      1.140000
# roll      110869.0  5.180797e+01      2.085821    30.890000     51.180000
# yaw       110869.0  2.009013e+02     84.477630     0.010000    162.430000
# mag_x     110869.0 -1.946527e+01     28.120202   -73.046240    -41.742792
# mag_y     110869.0 -1.174493e+00     15.655121   -43.810030    -12.982321
# mag_z     110869.0 -6.004529e+00      8.552481   -41.163040    -11.238430
# accel_x   110869.0 -6.303707e-04      0.000224    -0.025034     -0.000697
# accel_y   110869.0  1.850448e-02      0.000604    -0.005903      0.018009
# accel_z   110869.0  1.451158e-02      0.000312    -0.022900      0.014349
# gyro_x    110869.0 -8.959493e-07      0.002808    -0.303793     -0.000275
# gyro_y    110869.0  6.879912e-06      0.002456    -0.378412     -0.000278
# gyro_z    110869.0 -9.671594e-07      0.002133    -0.297080     -0.000120
# reset     110869.0  1.803931e-04      0.060065     0.000000      0.000000
#
#                    50%           75%            max
# ROW_ID    55435.000000  83152.000000  110869.000000
# temp_cpu     32.280000     32.480000      33.700000
# temp_h       28.110000     28.360000      29.280000
# temp_p       25.570000     25.790000      26.810000
# humidity     46.130000     46.880000      60.590000
# pressure   1007.650000   1010.270000    1021.780000
# pitch         1.450000      1.740000     360.000000
# roll         51.950000     52.450000     359.400000
# yaw         190.580000    256.340000     359.980000
# mag_x       -21.339485      7.299000      33.134748
# mag_y        -1.350467     11.912456      37.552135
# mag_z        -5.764400     -0.653705      31.003047
# accel_x      -0.000631     -0.000567       0.018708
# accel_y       0.018620      0.018940       0.041012
# accel_z       0.014510      0.014673       0.029938
# gyro_x       -0.000003      0.000271       0.215147
# gyro_y       -0.000004      0.000271       0.389499
# gyro_z       -0.000001      0.000119       0.269876
# reset         0.000000      0.000000      20.000000

# %% [markdown]
# ## Plotting

# %%
fig, ax = plt.subplots()
prova[['temp_cpu', 'temp_h', 'temp_p', 'humidity', 'reset']].plot(ax=ax, figsize=(16, 5))
ax.legend(['temp_cpu', 'temp_h', 'temp_p', 'humidity', 'reset'])
fig, ax = plt.subplots()
prova[['pressure']].plot(ax=ax, figsize=(16, 5))
ax.legend(['pressure'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
for metrics in [['pitch', 'roll', 'yaw'],
       ['mag_x', 'mag_y', 'mag_z'],
       ['accel_x', 'accel_y', 'accel_z'],
       ['gyro_x', 'gyro_y', 'gyro_z']]:
       legend = []
       for m in metrics:
              legend.append(m)
       fig, ax = plt.subplots()
       prova[metrics].plot(ax=ax, figsize=(16, 5))
       ax.legend(legend)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
colors = ['orange', 'blue', 'green', 'red']
c = 0
for metrics in ['pitch', 'roll', 'yaw', 'mag_x', 'mag_y', 'mag_z']:
       legend = []
       legend.append(metrics)
       fig, ax = plt.subplots()
       prova[metrics].plot(ax=ax, figsize=(16, 5), color=colors[c])
       ax.legend(legend)
       c = c + 1
       if c == 4:
              c = 0
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
for metrics in [['compass', 'pitch', 'roll', 'yaw'],
       ['magnetometer', 'mag_x', 'mag_y', 'mag_z'],
       ['accelerometer', 'accel_x', 'accel_y', 'accel_z'],
       ['gyroscope', 'gyro_x', 'gyro_y', 'gyro_z']]:
       fig = plt.figure(figsize=(10, 5))
       ax = plt.axes(projection='3d')
       ax.scatter3D(prova[metrics[1]], prova[metrics[2]], prova[metrics[3]], c=prova[metrics[3]], cmap='viridis');
       plt.title(metrics[0])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
