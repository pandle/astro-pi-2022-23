# %% [markdown]
# # ASTROPI CSV ANALYSIS

# %% [markdown]
# ## Loading csv file

# %%
# !git clone https://github.com/raspberrypilearning/astro-pi-flight-data-analysis
# Out:
# fatal: destination path 'astro-pi-flight-data-analysis' already exists and is not an empty directory.

# %%
import warnings
warnings.filterwarnings('ignore')

# %matplotlib widget
import matplotlib.pyplot as plt

import pandas as pd
prova = pd.read_csv('astro-pi-flight-data-analysis/data/astro_pi_data_20150824_085954.zip')

# %% [markdown]
# ## Exploring

# %%
prova.columns
# Out:
# Index(['ROW_ID', 'temp_cpu', 'temp_h', 'temp_p', 'humidity', 'pressure',
#        'pitch', 'roll', 'yaw', 'mag_x', 'mag_y', 'mag_z', 'accel_x', 'accel_y',
#        'accel_z', 'gyro_x', 'gyro_y', 'gyro_z', 'reset', 'time_stamp'],
#       dtype='object')

# %%
prova[['temp_cpu', 'temp_h', 'temp_p', 'humidity', 'pressure', 'time_stamp']].head()
# Out:
#    temp_cpu  temp_h  temp_p  humidity  pressure           time_stamp
# 0     35.51   26.85   26.03     60.50   1021.76  2015-08-20 23:58:30
# 1     35.44   26.85   26.03     60.48   1021.75  2015-08-20 23:58:40
# 2     35.29   26.86   26.03     60.43   1021.74  2015-08-20 23:58:51
# 3     35.31   26.86   26.02     60.46   1021.73  2015-08-20 23:59:00
# 4     35.20   26.87   26.02     60.45   1021.71  2015-08-20 23:59:10

# %%
prova[['temp_cpu', 'temp_h', 'temp_p', 'humidity', 'pressure', 'time_stamp']].tail()
# Out:
#        temp_cpu  temp_h  temp_p  humidity  pressure           time_stamp
# 24599     33.13   26.07   25.12     60.70   1001.73  2015-08-24 08:57:01
# 24600     32.95   26.08   25.12     60.72   1001.75  2015-08-24 08:57:10
# 24601     32.57   26.08   25.11     60.80   1001.74  2015-08-24 08:57:21
# 24602     32.52   26.09   25.11     60.58   1001.74  2015-08-24 08:57:30
# 24603     32.48   26.09   25.11     60.88   1001.74  2015-08-24 08:57:40

# %%
prova.describe().T
# Out:
#             count          mean          std          min          25%  \
# ROW_ID    24604.0  1.230250e+04  7102.707348     1.000000  6151.750000
# temp_cpu  24604.0  3.424935e+01     1.709287    31.820000    32.650000
# temp_h    24604.0  2.768828e+01     1.746560    25.600000    26.390000
# temp_p    24604.0  2.682050e+01     1.797350    24.660000    25.480000
# humidity  24604.0  5.809031e+01     3.533693    51.160000    55.110000
# pressure  24604.0  1.011727e+03     7.580105  1001.720000  1003.927500
# pitch     24604.0  2.862632e+02    31.604273   272.330000   272.500000
# roll      24604.0  5.591883e+01   118.310643     0.410000     9.290000
# yaw       24604.0  2.056634e+02    25.260212   190.780000   194.260000
# mag_x     24604.0  4.372833e+01    19.885399    -4.165530    51.872630
# mag_y     24604.0  2.105796e+01     1.610343    17.012031    20.331286
# mag_z     24604.0  5.000377e+01    10.137795    42.890589    45.342043
# accel_x   24604.0  8.461288e-01     0.359988     0.014794     1.001251
# accel_y   24604.0  6.544246e-03     0.003833    -0.033239     0.007111
# accel_z   24604.0  2.007738e-01     0.361551     0.041334     0.043586
# gyro_x    24604.0  5.737278e-07     0.000342    -0.025187    -0.000148
# gyro_y    24604.0 -7.269834e-06     0.001502    -0.087231    -0.000792
# gyro_z    24604.0 -7.649163e-07     0.000709    -0.061099    -0.000125
# reset     24604.0  1.625752e-03     0.180316     0.000000     0.000000
#
#                    50%           75%           max
# ROW_ID    12302.500000  18453.250000  24604.000000
# temp_cpu     33.930000     35.250000     38.530000
# temp_h       27.150000     28.470000     32.460000
# temp_p       26.280000     27.650000     31.680000
# humidity     58.060000     61.520000     65.740000
# pressure   1012.160000   1019.960000   1022.780000
# pitch       272.560000    272.630000    359.500000
# roll         10.020000     11.780000    359.920000
# yaw         195.270000    196.060000    283.230000
# mag_x        52.240873     52.549661     53.649157
# mag_y        20.595735     20.937554     32.609185
# mag_z        45.928488     46.446987     74.693409
# accel_x       1.001969      1.002553      1.005768
# accel_y       0.007479      0.008185      0.028923
# accel_z       0.044045      0.044975      1.038119
# gyro_x       -0.000001      0.000147      0.020280
# gyro_y       -0.000038      0.000773      0.076061
# gyro_z        0.000000      0.000126      0.067224
# reset         0.000000      0.000000     20.000000

# %% [markdown]
# ## Plotting

# %%
fig, ax = plt.subplots()
prova[['temp_cpu', 'temp_h', 'temp_p', 'humidity', 'reset']].plot(ax=ax, figsize=(16, 5))
ax.legend(['temp_cpu', 'temp_h', 'temp_p', 'humidity', 'reset'])
fig, ax = plt.subplots()
prova[['pressure']].plot(ax=ax, figsize=(16, 5))
ax.legend(['pressure'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
for metrics in [['pitch', 'roll', 'yaw'],
       ['mag_x', 'mag_y', 'mag_z'],
       ['accel_x', 'accel_y', 'accel_z'],
       ['gyro_x', 'gyro_y', 'gyro_z']]:
       legend = []
       for m in metrics:
              legend.append(m)
       fig, ax = plt.subplots()
       prova[metrics].plot(ax=ax, figsize=(16, 5))
       ax.legend(legend)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
for metrics in [['compass', 'pitch', 'roll', 'yaw'],
       ['magnetometer', 'mag_x', 'mag_y', 'mag_z'],
       ['accelerometer', 'accel_x', 'accel_y', 'accel_z'],
       ['gyroscope', 'gyro_x', 'gyro_y', 'gyro_z']]:
       fig = plt.figure(figsize=(10, 5))
       ax = plt.axes(projection='3d')
       ax.scatter3D(prova[metrics[1]], prova[metrics[2]], prova[metrics[3]], c=prova[metrics[3]], cmap='viridis');
       plt.title(metrics[0])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
